# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# !unzip /content/drive/MyDrive/datasets/dataset-pcb.zip -d /content/
# Out:
# Archive:  /content/drive/MyDrive/datasets/dataset-pcb.zip
#    creating: /content/dataset-pcb/images/
#    creating: /content/dataset-pcb/images/train/
#   inflating: /content/dataset-pcb/images/train/01_missing_hole_01.jpg
#   inflating: /content/dataset-pcb/images/train/01_missing_hole_02.jpg
#   inflating: /content/dataset-pcb/images/train/01_missing_hole_03.jpg
#   inflating: /content/dataset-pcb/images/train/01_missing_hole_05.jpg
#   inflating: /content/dataset-pcb/images/train/01_missing_hole_06.jpg
#   inflating: /content/dataset-pcb/images/train/01_missing_hole_08.jpg
#   inflating: /content/dataset-pcb/images/train/01_missing_hole_09.jpg
#   inflating: /content/dataset-pcb/images/train/01_missing_hole_10.jpg
#   inflating: /content/dataset-pcb/images/train/01_missing_hole_15.jpg
#   inflating: /content/dataset-pcb/images/train/01_missing_hole_17.jpg
#   inflating: /content/dataset-pcb/images/train/01_missing_hole_18.jpg
# ...

# %%
import os
os.getcwd()
# Out:
# '/content'

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.

# %%
cd yolov5
# Out:
# [Errno 2] No such file or directory: 'yolov5'
# /content/yolov5

# %%
# !pip install -r requirements.txt

# %%
# !python train.py --img 416 --batch 16 --epochs 40 --data dataset.yaml --weights yolov5m.pt --cache --name pcb_1stm
# Out:
# 2023-12-06 18:57:47.989842: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-06 18:57:47.989899: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-06 18:57:47.989937: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python val.py --weights runs/train/pcb_1stm2/weights/best.pt --data dataset.yaml
# Out:
# val: data=dataset.yaml, weights=['runs/train/pcb_1stm2/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-247-g3f02fde Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 212 layers, 20873139 parameters, 0 gradients, 47.9 GFLOPs
# val: Scanning /content/dataset-pcb/labels/val.cache... 138 images, 0 backgrounds, 0 corrupt: 100% 138/138 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:25<00:00,  5.11s/it]
#                    all        138        570      0.819      0.781       0.86      0.382
#           missing_hole        138         96      0.755      0.961      0.976      0.512
# ...

# %%
# !dir
# Out:
# benchmarks.py	 data	       hubconf.py   README.md	      segment	      Untitled\ Folder
# CITATION.cff	 dataset.yaml  LICENSE	    README.zh-CN.md   setup.cfg       utils
# classify	 detect.py     models	    requirements.txt  train.py	      val.py
# CONTRIBUTING.md  export.py     __pycache__  runs	      tutorial.ipynb  yolov5s.pt

# %%
# !python detect.py --source ../test_images/3.jpg  --weights runs/train/pcb_1st/weights/best.pt
# Out:
# detect: weights=['runs/train/pcb_1st/weights/best.pt'], source=../test_images/3.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-247-g3f02fde Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7026307 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/test_images/3.jpg: 480x640 26 missing_holes, 5 spurious_coppers, 51.3ms
# Speed: 0.5ms pre-process, 51.3ms inference, 1.6ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp6
